# %%
# !ls
# Out:
# 20201021_pandas.ipynb Untitled.ipynb        data

# %%
# !ls data/
# Out:
# optd_aircraft.csv weather_year.csv

# %%
import pandas as pd

# %%
w = pd.read_csv('data/weather_year.csv')

# %%
w.head()
# Out:
#          EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2012-3-10                56                 40                24
# 1  2012-3-11                67                 49                30
# 2  2012-3-12                71                 62                53
# 3  2012-3-13                76                 63                50
# 4  2012-3-14                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity  ...   Max VisibilityMiles  \
# 0              50             26  ...                    10
# ...

# %%
type(w.EDT[0])
# Out:
# str

# %%
w['EDT'][0]
# Out:
# '2012-3-10'

# %%
w = pd.read_csv('data/weather_year.csv', parse_dates=['EDT'])

# %%
w.head()
# Out:
#          EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2012-03-10                56                 40                24
# 1 2012-03-11                67                 49                30
# 2 2012-03-12                71                 62                53
# 3 2012-03-13                76                 63                50
# 4 2012-03-14                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity  ...   Max VisibilityMiles  \
# 0              50             26  ...                    10
# ...

# %%
w.EDT[0]
# Out:
# Timestamp('2012-03-10 00:00:00')

# %%
type(w.EDT[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(w['EDT'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
type(w.EDT)
# Out:
# pandas.core.series.Series

# %%
type(w)
# Out:
# pandas.core.frame.DataFrame

# %%
w.describe()
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# count        366.000000         366.000000        366.000000      366.000000
# mean          66.803279          55.683060         44.101093       49.549180
# std           20.361247          18.436506         17.301141       16.397178
# min           16.000000          11.000000          1.000000        0.000000
# 25%           51.000000          41.000000         30.000000       36.000000
# 50%           69.000000          59.000000         47.000000       54.500000
# 75%           84.000000          70.750000         57.750000       62.000000
# max          106.000000          89.000000         77.000000       77.000000
#
#        MeanDew PointF  Min DewpointF  Max Humidity   Mean Humidity  \
# count      366.000000     366.000000    366.000000      366.000000
# mean        44.057377      37.980874     90.027322       67.860656
# std         16.829996      17.479449      9.108438        9.945591
# ...

# %%
len(w)
# Out:
# 366

# %%
w.shape
# Out:
# (366, 23)

# %%
w.head()
# Out:
#          EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0 2012-03-10                56                 40                24
# 1 2012-03-11                67                 49                30
# 2 2012-03-12                71                 62                53
# 3 2012-03-13                76                 63                50
# 4 2012-03-14                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity  ...   Max VisibilityMiles  \
# 0              50             26  ...                    10
# ...

# %%
len(w.EDT.drop_duplicates())
# Out:
# 366

# %%
len(w.EDT)
# Out:
# 366

# %%
w = pd.read_csv('data/weather_year.csv', parse_dates=['EDT'], index_col='EDT')

# %%
w.head()
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# EDT
# 2012-03-10                56                 40                24
# 2012-03-11                67                 49                30
# 2012-03-12                71                 62                53
# 2012-03-13                76                 63                50
# 2012-03-14                80                 62                44
#
#             Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# EDT
# 2012-03-10              24              20             16            74
# 2012-03-11              43              31             24            78
# 2012-03-12              59              55             43            90
# 2012-03-13              57              53             47            93
# 2012-03-14              58              52             43            93
#
#              Mean Humidity   Min Humidity   Max Sea Level PressureIn  ...  \
# ...

# %%
w.plot()
# Out:
# <AxesSubplot:xlabel='EDT'>

# %%
w.head()
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# EDT
# 2012-03-10                56                 40                24
# 2012-03-11                67                 49                30
# 2012-03-12                71                 62                53
# 2012-03-13                76                 63                50
# 2012-03-14                80                 62                44
#
#             Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# EDT
# 2012-03-10              24              20             16            74
# 2012-03-11              43              31             24            78
# 2012-03-12              59              55             43            90
# 2012-03-13              57              53             47            93
# 2012-03-14              58              52             43            93
#
#              Mean Humidity   Min Humidity   Max Sea Level PressureIn  ...  \
# ...

# %%
t = w[['Max TemperatureF', 'Mean TemperatureF', 'Min TemperatureF']]

# %%
t.head()
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF
# EDT
# 2012-03-10                56                 40                24
# 2012-03-11                67                 49                30
# 2012-03-12                71                 62                53
# 2012-03-13                76                 63                50
# 2012-03-14                80                 62                44

# %%
t.plot()
# Out:
# <AxesSubplot:xlabel='EDT'>

# %%
t.drop(columns=['Mean TemperatureF'])
# Out:
#             Max TemperatureF  Min TemperatureF
# EDT
# 2012-03-10                56                24
# 2012-03-11                67                30
# 2012-03-12                71                53
# 2012-03-13                76                50
# 2012-03-14                80                44
# ...                      ...               ...
# 2013-03-06                32                29
# 2013-03-07                36                28
# 2013-03-08                47                23
# 2013-03-09                56                33
# 2013-03-10                60                50
#
# [366 rows x 2 columns]

# %%
t.head()
# Out:
#             Max TemperatureF  Mean TemperatureF  Min TemperatureF
# EDT
# 2012-03-10                56                 40                24
# 2012-03-11                67                 49                30
# 2012-03-12                71                 62                53
# 2012-03-13                76                 63                50
# 2012-03-14                80                 62                44

# %%
del(w)

# %%
t = t.drop(columns=['Mean TemperatureF'])

# %%
t.head()
# Out:
#             Max TemperatureF  Min TemperatureF
# EDT
# 2012-03-10                56                24
# 2012-03-11                67                30
# 2012-03-12                71                53
# 2012-03-13                76                50
# 2012-03-14                80                44

# %%
t.plot()
# Out:
# <AxesSubplot:xlabel='EDT'>

# %%
t[t['Max TemperatureF']>100]
# Out:
#             Max TemperatureF  Min TemperatureF
# EDT
# 2012-06-28               103                67
# 2012-06-29               103                74
# 2012-07-01               101                67
# 2012-07-04               101                73
# 2012-07-05               103                70
# 2012-07-06               104                69
# 2012-07-07               106                72
# 2012-07-25               101                74

# %%
t[t['Max TemperatureF']>100].shape
# Out:
# (8, 2)

# %%
len(t[t['Max TemperatureF']>100])
# Out:
# 8

# %%
t['Limit'] = 100

# %%
t.head()
# Out:
#             Max TemperatureF  Min TemperatureF  Limit
# EDT
# 2012-03-10                56                24    100
# 2012-03-11                67                30    100
# 2012-03-12                71                53    100
# 2012-03-13                76                50    100
# 2012-03-14                80                44    100

# %%
t.plot()
# Out:
# <AxesSubplot:xlabel='EDT'>

# %%
def f2c(f):
    return (f-32)/1.8

# %%
f2c(100)
# Out:
# 37.77777777777778

# %%
c = t['Max TemperatureF']

# %%
c.map(f2c)
# Out:
# EDT
# 2012-03-10    13.333333
# 2012-03-11    19.444444
# 2012-03-12    21.666667
# 2012-03-13    24.444444
# 2012-03-14    26.666667
#                 ...
# 2013-03-06     0.000000
# 2013-03-07     2.222222
# 2013-03-08     8.333333
# 2013-03-09    13.333333
# 2013-03-10    15.555556
# Name: Max TemperatureF, Length: 366, dtype: float64

# %%
type(c.map(f2c))
# Out:
# pandas.core.series.Series

# %%
t['Max TemperatureC'] = t['Max TemperatureF'].map(f2c)

# %%
t['Min TemperatureC'] = t['Min TemperatureF'].map(f2c)

# %%
t['LimitC'] = t['Limit'].map(f2c)

# %%
t.head()
# Out:
#             Max TemperatureF  Min TemperatureF  Limit  Max TemperatureC  \
# EDT
# 2012-03-10                56                24    100         13.333333
# 2012-03-11                67                30    100         19.444444
# 2012-03-12                71                53    100         21.666667
# 2012-03-13                76                50    100         24.444444
# 2012-03-14                80                44    100         26.666667
#
#             Min TemperatureC     LimitC
# EDT
# 2012-03-10         -4.444444  37.777778
# 2012-03-11         -1.111111  37.777778
# 2012-03-12         11.666667  37.777778
# 2012-03-13         10.000000  37.777778
# 2012-03-14          6.666667  37.777778

# %%
t.pivot(columns=['Max TemperatureF'],values=['Limit'])
# Out:
#                  Limit                                      ...              \
# Max TemperatureF   16  18  24  25  26  27  28  29  30  31   ... 95  96  97
# EDT                                                         ...
# 2012-03-10         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2012-03-11         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2012-03-12         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2012-03-13         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2012-03-14         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# ...                ...  ..  ..  ..  ..  ..  ..  ..  ..  ..  ...  ..  ..  ..
# 2013-03-06         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2013-03-07         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# 2013-03-08         NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN  ... NaN NaN NaN
# ...
